# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 경로 설정

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.keras'

# %% [markdown]
# # 분류 수 설정

# %%
NUM_CLASSES = 7

# %% [markdown]
# # 학습 데이터 로드

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # 모델 구성

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20)             │           860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │            77 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,147 (4.48 KB)
#  Trainable params: 1,147 (4.48 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 모델 체크포인트 콜백
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 조기 종료 콜백
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# 모델 컴파일
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # 모델 학습

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1322 - loss: 2.2825
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 1: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.1467 - loss: 2.1784 - val_accuracy: 0.1566 - val_loss: 1.8342
# Epoch 2/1000
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1979 - loss: 1.9549
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 2: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2161 - loss: 1.9112 - val_accuracy: 0.3923 - val_loss: 1.6869
# Epoch 3/1000
# 45/48 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2661 - loss: 1.8021
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 3: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2696 - loss: 1.7960 - val_accuracy: 0.5137 - val_loss: 1.5937
# Epoch 4/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3003 - loss: 1.7153
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 4: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3051 - loss: 1.7092 - val_accuracy: 0.4744 - val_loss: 1.5187
# Epoch 5/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3302 - loss: 1.6530
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 5: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3417 - loss: 1.6367 - val_accuracy: 0.5564 - val_loss: 1.4460
# Epoch 6/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3624 - loss: 1.5939
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 6: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3686 - loss: 1.5756 - val_accuracy: 0.5530 - val_loss: 1.3832
# Epoch 7/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4082 - loss: 1.4988
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 7: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4046 - loss: 1.5101 - val_accuracy: 0.5599 - val_loss: 1.3323
# Epoch 8/1000
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4206 - loss: 1.4857
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 8: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4213 - loss: 1.4707 - val_accuracy: 0.5639 - val_loss: 1.2833
# Epoch 9/1000
# 45/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4355 - loss: 1.4453
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 9: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4351 - loss: 1.4373 - val_accuracy: 0.5753 - val_loss: 1.2434
# Epoch 10/1000
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4421 - loss: 1.4056
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 10: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4411 - loss: 1.4052 - val_accuracy: 0.5823 - val_loss: 1.2033
# Epoch 11/1000
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4605 - loss: 1.3719
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 11: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4651 - loss: 1.3672 - val_accuracy: 0.5624 - val_loss: 1.1794
# Epoch 12/1000
# 45/48 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4840 - loss: 1.3339
# Epoch 50: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 50: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4745 - loss: 1.3387 - val_accuracy: 0.5813 - val_loss: 1.1275
# Epoch 51/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4476 - loss: 1.3911
# Epoch 51: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 51: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4605 - loss: 1.3554 - val_accuracy: 0.5057 - val_loss: 1.1127
# Epoch 52/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4699 - loss: 1.3494
# Epoch 52: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 52: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4692 - loss: 1.3457 - val_accuracy: 0.5967 - val_loss: 1.0424
# Epoch 53/1000
# 46/48 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4607 - loss: 1.3523
# Epoch 53: saving model to model/keypoint_classifier/keypoint_classifier.keras
#
# Epoch 53: finished saving model to model/keypoint_classifier/keypoint_classifier.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4762 - loss: 1.3397 - val_accuracy: 0.6221 - val_loss: 1.0797
# Epoch 53: early stopping

# %%
# 모델 평가
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6221 - loss: 1.0797

# %%
# 저장된 모델 로드
model = tf.keras.models.load_model(model_save_path)

# %%
# 추론 테스트
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [0.43969142 0.12428871 0.1340809  0.08841001 0.08904158 0.05741198
#  0.06707534]
# 0

# %% [markdown]
# # 혼동 행렬

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.48      0.79      0.60       296
#            1       0.63      0.97      0.76       238
#            2       0.95      1.00      0.97       225
#            3       0.77      0.52      0.62       468
#            4       0.52      0.67      0.59       435
#            5       0.64      0.09      0.16       276
#            6       0.00      0.00      0.00        73
#
#     accuracy                           0.62      2011
#    macro avg       0.57      0.58      0.53      2011
# weighted avg       0.63      0.62      0.58      2011
# /opt/homebrew/Caskroom/miniconda/base/envs/tf-mac-metal/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/tf-mac-metal/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/homebrew/Caskroom/miniconda/base/envs/tf-mac-metal/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # TensorFlow Lite 모델로 변환

# %%
# 추론 전용 모델로 저장 (.keras 포맷 — HDF5 크래시 회피)
model.save(model_save_path, include_optimizer=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TFLite 변환은 별도 스크립트로 실행 (커널 크래시 방지)
# 터미널에서: conda run -n tf-mac-metal python convert_to_tflite.py
print("convert_to_tflite.py 를 터미널에서 실행하세요.")

# %% [markdown]
# # 추론 테스트 (TFLite)

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# 입출력 텐서 취득
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 추론 실행
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
